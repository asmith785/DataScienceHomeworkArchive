# %% [markdown]
# <div style="background: #000;
#             color: #FFF;
#             margin: 0px;
#                 padding: 10px 0px 20px 0px;
#             text-align: center;
#                 ">
#     <h1>Week 9 - Lab 1</h1>
# </div>

# %%
import pandas as pd

# %% [markdown]
# # Exercise 1
#
# Follow the instruction given and install the Pandas Library in VS Code. After installation, input a picture to document that you have successfully installed the Pandas Library.
#
# https://pypi.org/project/pandas/
#
# In a New Terminal: Should be pypi:
#
#     pip install pandas
#
# If you have the latest version of python:
#
#     pip3 install pandas
#
# Once you have the library create a simple dataframe of your choosing. Show your code.

# %% [markdown]
# ![Screen Shot 2021-11-08 at 8.14.36 PM.png](data:image/png;base64,...)

# %% [markdown]
# ![Screen Shot 2021-11-14 at 10.31.01 AM.png](data:image/png;base64,...)

# %% [markdown]
# # Exercise 2
#
# Create a data frame using pandas that uses a conditional statement other than if ascending = false.

# %%
x = pd.DataFrame(
    {
        "First_Name" : ["Antone", "Goku", "Yusuke", "Bob"],
        "Last_Name" : ["Smith", "Rider", "Yuremeshi", "Astro"]
    })

# %%
x
# Out:
#   First_Name  Last_Name
# 0     Antone      Smith
# 1       Goku      Rider
# 2     Yusuke  Yuremeshi
# 3        Bob      Astro

# %%
x.sort_values(by=['First_Name'])
# Out:
#   First_Name  Last_Name
# 0     Antone      Smith
# 3        Bob      Astro
# 1       Goku      Rider
# 2     Yusuke  Yuremeshi

# %% [markdown]
# # Exercise 3
#
# Create a Data Frame using pandas with Names and Age and change the datatype of age from int to str.

# %%
x3 = pd.DataFrame({"Names": ["Bill", "Bob", "Joesy"], "Age" : [45, 40, 25]})

# %%
x3.dtypes
# Out:
# Names    object
# Age       int64
# dtype: object

# %%
x3['Age'] = x3['Age'].astype('str')
x3.dtypes
# Out:
# Names    object
# Age      object
# dtype: object

# %% [markdown]
# # Exercise 4
#
# Write a data frame using pandas that contains a dictionary of column1 of 5 strings of letters, a column2 of 5 integers, another column3 of 5 integers and a column4 of 5 strings of letters with lower and upper cases.

# %%
x4 = pd.DataFrame({"Col_1" :["a", "b", "c", "d", "e"],
"Col_2" : [1,2,3,4,5],
"Col_3" : [6,7,8,9,10],
"Col_4" : ["A", "f", "Z", "J", "w" ]})

# %%
x4
# Out:
#   Col_1  Col_2  Col_3 Col_4
# 0     a      1      6     A
# 1     b      2      7     f
# 2     c      3      8     Z
# 3     d      4      9     J
# 4     e      5     10     w

# %% [markdown]
# # Bonus Question
#
# Write a Pandas program that contains data of a student for each column (you can create as many as you think are necessary). Make sure to display the default index and set a column as an Index in the dataframe. Output only one of the columns of your choice and change its datatype.

# %%
x4b = pd.DataFrame(
    {
        "Student_number" : [5, 6, 7, 8],
        "Student_major" : ["Fashion", "Education", "Gen Studies", "Business" ],
        "Student_Average" : [90.5, 75.0, 84.5, 95.0]
    })

# %%
x4b.dtypes
# Out:
# Student_number       int64
# Student_major       object
# Student_Average    float64
# dtype: object

# %%
x4b
# Out:
#    Student_number Student_major  Student_Average
# 0               5       Fashion             90.5
# 1               6     Education             75.0
# 2               7   Gen Studies             84.5
# 3               8      Business             95.0

# %%
x4b.Student_Average
# Out:
# 0    90.5
# 1    75.0
# 2    84.5
# 3    95.0
# Name: Student_Average, dtype: float64

# %%
x4b['Student_Average'] = x4b['Student_Average'].astype('str')
x4b.dtypes
# Out:
# Student_number      int64
# Student_major      object
# Student_Average    object
# dtype: object
